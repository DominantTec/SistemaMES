# %% [markdown]
# # 1. Imports

# %%
from pymodbus.client import ModbusTcpClient

# %% [markdown]
# # 2. Connection

# %%
client = ModbusTcpClient(host="192.168.11.89", port=5900, timeout=1)

# %%
if not client.connect():
    print("Não conectou no servidor Modbus")
else:
    rr = client.read_holding_registers(address=0, count=1, slave=1)
    print(rr)
    client.close()
# Out:
# Connection to (192.168.11.89, 5900) failed: timed out
# Não conectou no servidor Modbus
